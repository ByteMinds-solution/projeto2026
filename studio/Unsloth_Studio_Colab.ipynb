# %% [markdown]
# <a href="https://colab.research.google.com/github/ByteMinds-solution/projeto2026/blob/main/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Studio Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh --local
# Out:
# Cloning into 'unsloth'...
# remote: Enumerating objects: 1254, done.
# remote: Counting objects: 100% (1254/1254), done.
# remote: Compressing objects: 100% (1071/1071), done.
# remote: Total 1254 (delta 187), reused 849 (delta 160), pack-reused 0 (from 0)
# Receiving objects: 100% (1254/1254), 33.76 MiB | 16.44 MiB/s, done.
# Resolving deltas: 100% (187/187), done.
# /content/unsloth
#
#   🦥 Unsloth Studio Setup
#   ────────────────────────────────────────────────────
#                  local mode: overlaying /content/unsloth (editable) + unsloth-zoo from git main
#                  upgrading npm...
#   node           v20.19.0 | npm 11.13.0
#                  installing bun...
#                  bun installed (1.3.13)
#                  building frontend...
#                  using bun for package install (faster)
#   frontend       built
#                  Colab detected, installing Studio backend dependencies...
#   python         backend deps installed into system Python
#                  continuing to llama.cpp install for GGUF inference support
#   deps           [==------------------]  2/14  base packages         deps           overlaying local repo (editable): /content/unsloth
#   deps           overlaying unsloth-zoo from git main
#   deps           [====================] 14/14  ROCm torch (final)
#   deps           installed
#   transformers   5.3.0 pre-installed
#   transformers   5.5.0 pre-installed
#                  installing prebuilt llama.cpp...
#   llama.cpp      prebuilt installed and validated
#                  installed release: unslothai/llama.cpp@b8955
#
#   ────────────────────────────────────────────────────
#   Unsloth Studio Setup Complete
#   ────────────────────────────────────────────────────
#                  from colab import start
#                  start()

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys, time
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start
start()
# Out:
# 2026-05-02 17:05:26 [info     ] 🦥 Starting Unsloth Studio...
# 2026-05-02 17:05:26 [info     ]    Loading backend...
# 2026-05-02 17:05:26 [info     ]    Starting server...
# INFO:     Started server process [18307]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8888 (Press CTRL+C to quit)
# Hardware detected: CUDA -- Tesla T4
#
# ============================================================
# DEFAULT ADMIN ACCOUNT CREATED
#     username: unsloth
#     password saved to: /root/.unsloth/studio/auth/.bootstrap_password
#     Open the Studio UI to sign in and change it.
# ============================================================
#
# {"timestamp": "2026-05-02T17:05:35.384480Z", "level": "info", "event": "Pre-caching helper GGUF: unsloth/gemma-4-E2B-it-GGUF/gemma-4-E2B-it-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-05-02T17:05:36.589251Z", "level": "info", "event": "   Server started!"}
#     <div style="display: inline-block; padding: 20px; background: #ffffff; border: 2px solid #000000;
#                 border-radius: 12px; margin: 10px 0; font-family: system-ui, -apple-system, sans-serif;">
#         <h2 style="color: #000000; margin: 0 0 12px 0; font-size: 26px; font-weight: 800;
#                    display: flex; align-items: center; gap: 12px;">
#             <img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/unsloth-gem.png"
#                  height="48" style="display:block;">
#             Unsloth Studio is Ready!
#         </h2>
#         <a href="https://8888-gpu-t4-s-kkb-ass1c0-lwej84fsc0jr-c.asia-southeast1-0.prod.colab.dev" target="_blank"
#            style="display: inline-flex; align-items: center; gap: 10px; padding: 14px 28px;
#                   background: #000000; color: white; text-decoration: none; border-radius: 8px;
#                   font-weight: 800; font-size: 16px;">
#             <svg xmlns="http://www.w3.org/2000/svg" width="18" height="18" viewBox="0 0 24 24" fill="white"><polygon points="5,3 19,12 5,21"/></svg>
#             Open Unsloth Studio
#         </a>
#         <p style="color: #333333; margin: 12px 0 0 0; font-size: 14px; font-weight: bold;">
#             If the link doesn't work, you can scroll down to view the UI generated directly in Colab.
#         </p>
#         <p style="color: #333333; margin: 16px 0 0 0; font-size: 13px; font-family: monospace; font-weight: bold;">
#             https://8888-gpu-...
#         </p>
#     </div>

# %%
from google.colab import output
output.serve_kernel_port_as_iframe(8888, height = 1200, width = "100%")
for _ in range(10000): time.sleep(300), print("=", end = "")
# Out:
# {"timestamp": "2026-05-02T17:05:45.947487Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 11.4}
# {"timestamp": "2026-05-02T17:05:51.130205Z", "level": "info", "event": "Helper GGUF cached: 1 file(s)"}
# {"timestamp": "2026-05-02T17:06:01.126562Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 1.12}
# {"timestamp": "2026-05-02T17:06:01.830176Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.13}
# {"timestamp": "2026-05-02T17:06:02.477853Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.46}
# {"timestamp": "2026-05-02T17:06:03.913513Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.11}
# {"timestamp": "2026-05-02T17:08:09.256318Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/login", "status_code": 200, "process_time_ms": 78.87}
# {"timestamp": "2026-05-02T17:08:26.389088Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/change-password", "status_code": 200, "process_time_ms": 161.93}
# {"timestamp": "2026-05-02T17:08:29.690365Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.83}
# {"timestamp": "2026-05-02T17:08:30.065738Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.76}
# {"timestamp": "2026-05-02T17:08:30.825449Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 5.12}
# {"timestamp": "2026-05-02T17:08:30.830802Z", "level": "info", "event": "InferenceOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-05-02T17:08:30.834667Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api
bit', 'unsloth/gemma-3n-E4B-it', 'unsloth/Qwen2.5-3B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3-0.6B-unsloth-bnb-4bit', 'unsloth/Qwen3-4B-unsloth-bnb-4bit', 'unsloth/Qwen2.5-7B-Instruct-unsloth-bnb-4bit', 'unsloth/DeepSeek-OCR-2', 'unsloth/Qwen3-8B-unsloth-bnb-4bit', 'unsloth/gemma-4-E2B-it-unsloth-bnb-4bit', 'unsloth/gemma-4-26B-A4B-it', 'unsloth/Qwen3.6-35B-A3B-UD-MLX-4bit', 'unsloth/Qwen2.5-0.5B-Instruct', 'unsloth/Qwen3.5-2B', 'unsloth/Qwen3-VL-4B-Instruct', 'unsloth/Qwen3.5-0.8B', 'unsloth/Qwen2.5-3B-Instruct-bnb-4bit', 'unsloth/Qwen3-4B-Instruct-2507', 'unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit']"}
# {"timestamp": "2026-05-02T17:08:31.406766Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.71}
# {"timestamp": "2026-05-02T17:08:31.777749Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 7.0}
# {"timestamp": "2026-05-02T17:08:31.783796Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-05-02T17:08:31.785247Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-05-02T17:08:31.786615Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 7.11}
# {"timestamp": "2026-05-02T17:08:31.794791Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.61}
# {"timestamp": "2026-05-02T17:08:32.738176Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.9}
# {"timestamp": "2026-05-02T17:08:48.599996Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-models", "status_code": 200, "process_time_ms": 7.9}
# {"timestamp": "2026-05-02T17:08:48.601346Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/cached-gguf", "status_code": 200, "process_time_ms": 9.08}
# {"timestamp": "2026-05-02T17:08:50.283328Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/gguf-variants", "status_code": 200, "process_time_ms": 279.27}
# {"timestamp": "2026-05-02T17:08:51.179151Z", "level": "info", "event": "Detected remote GGUF repo 'unsloth/gemma-4-E2B-it-GGUF', variant=UD-Q4_K_XL, vision=True"}
# {"timestamp": "2026-05-02T17:08:51.190263Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-05-02T17:08:51.200166Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/validate", "status_code": 200, "process_time_ms": 520.52}
# {"timestamp": "2026-05-02T17:08:52.099985Z", "level": "info", "event": "Detected remote GGUF repo 'unsloth/gemma-4-E2B-it-GGUF', variant=UD-Q4_K_XL, vision=True"}
# {"timestamp": "2026-05-02T17:08:52.593019Z", "level": "info", "event": "Resolving GGUF: unsloth/gemma-4-E2B-it-GGUF/gemma-4-E2B-it-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-05-02T17:08:52.843473Z", "level": "info", "event": "GGUF resolved from cache: /root/.cache/huggingface/hub/models--unsloth--gemma-4-E2B-it-GGUF/snapshots/f064409f340b34190993560b2168133e5dbae558/gemma-4-E2B-it-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-05-02T17:08:53.089316Z", "level": "info", "event": "Downloading mmproj: unsloth/gemma-4-E2B-it-GGUF/mmproj-F16.gguf"}
# mmproj-F16.gguf:   0%|          | 0.00/986M [00:00<?, ?B/s]
# {"timestamp": "2026-05-02T17:09:07.283831Z", "level": "info", "event": "GGUF metadata: context_length=131072"}
# {"timestamp": "2026-05-02T17:09:07.284657Z", "level": "info", "event": "GGUF metadata: chat_template=16317 chars"}
# {"timestamp": "2026-05-02T17:09:07.285345Z", "level": "info", "event": "GGUF metadata: model supports reasoning (enable_thinking)"}
# {"timestamp": "2026-05-02T17:09:07.286858Z", "level": "info", "event": "GGUF metadata: model supports tool calling"}
# {"timestamp": "2026-05-02T17:09:07.314979Z", "level": "info", "event": "GGUF size: 3.0 GB, est. KV cache: 2.0 GB, context: 131072, GPUs free: [(0, 14910)], selected: [0], fit: False"}
# {"timestamp": "2026-05-02T17:09:07.316125Z", "level": "info", "event": "Reasoning model: {'enable_thinking': True} by default"}
# {"timestamp": "2026-05-02T17:09:07.316779Z", "level": "info", "event": "Using mmproj for vision: /root/.cache/huggingface/hub/models--unsloth--gemma-4-E2B-it-GGUF/snapshots/f064409f340b34190993560b2168133e5dbae558/mmproj-F16.gguf"}
# {"timestamp": "2026-05-02T17:09:07.317604Z", "level": "info", "event": "Starting llama-server: /root/.unsloth/llama.cpp/llama-server -m /root/.cache/huggingface/hub/models--unsloth--gemma-4-E2B-it-GGUF/snapshots/f064409f340b34190993560b2168133e5dbae558/gemma-4-E2B-it-UD-Q4_K_XL.gguf --port 36133 -c 131072 --parallel 1 --flash-attn on --no-context-shift -ngl -1 --threads -1 --jinja --chat-template-kwargs {\"enable_thinking\": true} --mmproj /root/.cache/huggingface/hub/models--unsloth--gemma-4-E2B-it-GGUF/snapshots/f064409f340b34190993560b2168133e5dbae558/mmproj-F16.gguf"}
# {"timestamp": "2026-05-02T17:09:24.611118Z", "level": "info", "event": "llama-server ready on port 36133 for model 'unsloth/gemma-4-E2B-it-GGUF'"}
# {"timestamp": "2026-05-02T17:09:24.612127Z", "level": "info", "event": "Loaded GGUF model via llama-server: unsloth/gemma-4-E2B-it-GGUF"}
# {"timestamp": "2026-05-02T17:09:24.678823Z", "level": "info", "event": "Loaded default model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/default.yaml"}
# {"timestamp": "2026-05-02T17:09:24.689943Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/inference/load", "status_code": 200, "process_time_ms": 33111.64}
# {"timestamp": "2026-05-02T17:09:30.511046Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 26.02}
# ={"timestamp": "2026-05-02T17:14:56.527963Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/v1/chat/completions", "status_code": 200, "process_time_ms": 14.78}
# ====

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
